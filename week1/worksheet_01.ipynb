# %% [markdown]
# # **Worksheet - 1**

# %% [markdown]
# # Exercise- 1

# %% [markdown]
# 1. Read and display the image.
#
# • Read the image using the Pillow library and display it.
#
# • You can also use matplotlib to display the image.

# %%
from PIL import Image
import numpy as np

# %%
image = Image.open("/content/spiderman.png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=512x512>

# %% [markdown]
# 2. Display only the top left corner of 100x100 pixels.
#
# • Extract the top-left corner of the image (100x100 pixels) and display it using NumPy and Array Indexing.

# %%
# Convert the image to a NumPy array
img_array = np.array(image)
cropped_image = img_array[0:100, 0:100, :]
Image.fromarray(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100>

# %% [markdown]
# 3. Show the three color channels (R, G, B).
#
# • Separate the image into its three color channels (Red, Green, and Blue) and display them individually, labeling each channel as R, G, and B.{Using NumPy.}

# %%
test = img_array.copy()

# %%
import matplotlib.pyplot as plt

# %%
test[:,:,0]=0
test[:,:,1]=0
# display(test)
plt.imshow(test)

# %%
# For Blue Channel :
blue_channel = img_array[: , : , 2] # Blue channel
print ( blue_channel )
display ( blue_channel )
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
# For Red Channel :
red_channel = img_array[: , : , 0] # Red channel
print ( red_channel )
display ( red_channel )
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
# For Green Channel :
green_channel = img_array[: , : , 1] # Green channel
print ( green_channel )
display ( green_channel )
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %% [markdown]
# 4. Modify the top 100 × 100 pixels to a value of 210 and display the resulting image:
#
# • Modify the pixel values of the top-left 100 × 100 region to have a value of 210 (which is a light gray color), and then display the modified image.

# %%
copy_1 = img_array.copy()

# %%
copy_1[:100,:100] = 210

# %%
copy_1
# Out:
# array([[[210, 210, 210, 210],
#         [210, 210, 210, 210],
#         [210, 210, 210, 210],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[210, 210, 210, 210],
#         [210, 210, 210, 210],
#         [210, 210, 210, 210],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[210, 210, 210, 210],
#         [210, 210, 210, 210],
#         [210, 210, 210, 210],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        ...,
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]]], dtype=uint8)

# %%
Image.fromarray(copy_1)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512>

# %% [markdown]
# # Exercise-2

# %% [markdown]
# 1. Load and display a grayscale image.
#
# • Load a grayscale image using the Pillow library.
#
# • Display the grayscale image using matplotlib.

# %%
image_gray = Image.open("/content/lena_gray.gif")
plt.imshow(image_gray)

# %% [markdown]
# Extract and display the middle section of the image (150 pixels).
#
# • Extract a 150 pixel section from the center of the image using NumPy array slicing.
#
# • Display this cropped image using matplotlib.

# %%
array = np.array(image_gray)

# %%
cropped_array = array[250:400, 250:400]

# %%
cropped_array
# Out:
# array([[210, 209, 101, ...,  75,  75,  69],
#        [102,  99, 205, ...,  73, 175, 171],
#        [207, 205, 204, ..., 179, 169, 171],
#        ...,
#        [ 27,  25, 133, ...,  26,  24,  29],
#        [134, 133,  26, ..., 132, 133,  26],
#        [136,  26,  27, ...,  24, 134,  23]], dtype=uint8)

# %% [markdown]
# 3. Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).
#
# • Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values above 100 to 255 (creating a binary image).
#
# • Display the resulting binary image.

# %%
array_copy = array.copy()

# %%
result = np.where(array_copy < 100, 0, 255)

# %%
result
# Out:
# array([[255, 255, 255, ..., 255,   0, 255],
#        [255, 255, 255, ..., 255,   0, 255],
#        [255, 255, 255, ..., 255,   0, 255],
#        ...,
#        [  0,   0, 255, ..., 255, 255, 255],
#        [255, 255,   0, ..., 255,   0, 255],
#        [255, 255,   0, ..., 255,   0, 255]])

# %%
plt.imshow(result)

# %% [markdown]
# 4. Rotate the image 90 degrees clockwise and display the result.
#
# • Rotate the image by 90 degrees clockwise using the Pillow rotate method or by manipulating
# the image array.
#
# • Display the rotated image using matplotlib.

# %%
image_gray = image_gray.rotate(90)

# %%
image_gray
# Out:
# <PIL.Image.Image image mode=P size=512x512>

# %% [markdown]
# 5. Convert the grayscale image to an RGB image.
#
# • Convert the grayscale image into an RGB image where the grayscale values are replicated across all three channels (R, G, and B).
#
# • Display the converted RGB image using matplotlib.

# %%
image_gray_copy = Image.open("/content/lena_gray.gif")

# %%
img_array = np.array(image_gray_copy)
img_rgb = np.stack((img_array, img_array, img_array), axis=-1)
plt.imshow(img_rgb)

# %% [markdown]
# # Image Compression and Decompression using PCA.
